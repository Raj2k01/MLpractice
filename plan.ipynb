# %% [markdown]
# Python [x]
#   ↓
# NumPy [x]
#   ↓
# Pandas [x]
#   ↓
# Matplotlib + Seaborn [x]
#   ↓
# Statistics and Probability [x]
#   ↓
# Data Cleaning + EDA [x]
#   ↓
# Feature Engineering [x]
#   ↓
# Scikit-learn Preprocessing [x]
#   ↓
# Supervised Machine Learning []
#   ↓
# Model Evaluation
#   ↓
# Unsupervised Machine Learning
#   ↓
# Pipelines + Hyperparameter Tuning
#   ↓
# XGBoost / LightGBM / CatBoost
#   ↓
# SQL for ML
#   ↓
# End-to-End ML Projects
#   ↓
# FastAPI + Model Deployment
#   ↓
# Docker + Git
#   ↓
# MLOps
#   ↓
# PyTorch and Deep Learning
#   ↓
# Specialization: NLP / Computer Vision / GenAI

# %% [markdown]
# | Day | Main topic                        | Output                           |
# | --: | --------------------------------- | -------------------------------- |
# |   1 | Python for ML                     | Core Python notebooks            |
# |   2 | NumPy                             | Vectorized numerical analysis    |
# |   3 | Pandas                            | Data-cleaning notebook           |
# |   4 | Matplotlib and Seaborn            | EDA report                       |
# |   5 | Statistics                        | Statistical analysis notebook    |
# |   6 | Preprocessing                     | Reusable preprocessing functions |
# |   7 | Linear and regularized regression | House-price baseline             |
# |   8 | Logistic regression and KNN       | Classification baseline          |
# |   9 | Decision trees and Random Forest  | Model comparison                 |
# |  10 | Metrics and validation            | Evaluation report                |
# |  11 | Feature engineering and selection | Improved feature set             |
# |  12 | Clustering and PCA                | Customer segmentation            |
# |  13 | XGBoost and class imbalance       | Churn model                      |
# |  14 | Pipelines and tuning              | Production-style pipeline        |
# |  15 | Complete project                  | End-to-end repository            |
# |  16 | FastAPI and serialization         | Prediction API                   |
# |  17 | Docker and testing                | Containerized API                |
# |  18 | SageMaker deployment              | Cloud inference workflow         |
# |  19 | PyTorch fundamentals              | Neural-network classifier        |
# |  20 | Interview and project explanation | Mock interview                   |

# %% [markdown]
# What to Prioritize for an ML Engineer Interview
# Tier 1: Mandatory
# Python
# NumPy
# Pandas
# SQL
# Statistics
# EDA
# Data preprocessing
# Feature engineering
# Scikit-learn
# Regression and classification
# Evaluation metrics
# Cross-validation
# Bias and variance
# Pipelines
# Hyperparameter tuning
# Trees, Random Forest and XGBoost
# Git
# One end-to-end project
# Tier 2: Strong differentiators
# SHAP
# FastAPI
# Docker
# AWS SageMaker
# Model monitoring
# MLflow
# Imbalanced learning
# Testing and logging
# Tier 3: Learn after becoming strong in Tier 1
# PyTorch
# CNNs
# Transformers
# NLP
# Computer vision
# RAG and GenAI
# Advanced MLOps

# %% [markdown]
# 1. Matplotlib and Seaborn
#
# Learn visualization immediately after Pandas because you need it for EDA and model analysis.
#
# Matplotlib
#
# Cover:
#
# Line plots
# Bar charts
# Histograms
# Scatter plots
# Box plots
# Subplots
# Figure size
# Titles and labels
# Legends
# Saving figures
# Seaborn
#
# Cover:
#
# histplot()
# countplot()
# barplot()
# boxplot()
# violinplot()
# scatterplot()
# pairplot()
# heatmap()
# ML applications
#
# You must know how to visualize:
#
# Feature distributions
# Missing values
# Outliers
# Class imbalance
# Feature relationships
# Correlation matrix
# Actual versus predicted values
# Confusion matrix
# Feature importance
# Training and validation loss
# 2. Statistics and Probability for ML
#
# You do not need advanced mathematics initially, but you need strong practical understanding.
#
# Descriptive statistics
#
# Learn:
#
# Mean
# Median
# Mode
# Minimum and maximum
# Range
# Variance
# Standard deviation
# Percentiles
# Quartiles
# Interquartile range
# Covariance
# Correlation
# Probability
#
# Learn:
#
# Probability basics
# Conditional probability
# Independent and dependent events
# Bayes’ theorem
# Joint and marginal probability
# Expected value
# Distributions
#
# Learn:
#
# Normal distribution
# Bernoulli distribution
# Binomial distribution
# Poisson distribution
# Uniform distribution
# Skewed distributions
# Inferential statistics
#
# Learn:
#
# Population versus sample
# Sampling techniques
# Central Limit Theorem
# Confidence intervals
# Hypothesis testing
# Null and alternative hypotheses
# P-value
# Type I and Type II errors
# Z-test
# T-test
# Chi-square test
# ANOVA
# Interview focus
#
# You should be able to explain:
#
# Why median is preferred for skewed data
# Correlation versus causation
# Covariance versus correlation
# What a p-value means
# Type I versus Type II error
# Why normal distribution is important
# How outliers affect mean and standard deviation
# 3. Data Cleaning and Exploratory Data Analysis
#
# This is one of the most important practical ML skills.
#
# Data quality checks
#
# Learn to identify:
#
# Missing values
# Duplicate records
# Incorrect data types
# Invalid categories
# Impossible values
# Inconsistent units
# Outliers
# Data leakage
# Class imbalance
# Missing-value handling
#
# Learn when to use:
#
# Row removal
# Column removal
# Mean imputation
# Median imputation
# Mode imputation
# Constant-value imputation
# Group-based imputation
# SimpleImputer
# KNNImputer
#
# Do not automatically replace every missing numeric value with the mean.
#
# Outlier handling
#
# Learn:
#
# IQR method
# Z-score method
# Percentile capping
# Winsorization
# Log transformation
# RobustScaler
# Domain-based validation
# EDA workflow
#
# For every dataset:
#
# Understand the business problem.
# Identify the target variable.
# Check shape and schema.
# Check data types.
# Study missing values.
# Find duplicates.
# Analyze numerical distributions.
# Analyze categorical distributions.
# Detect outliers.
# Study target distribution.
# Examine feature relationships.
# Check correlation.
# Look for leakage.
# Record observations and preprocessing decisions.
# 4. Feature Engineering
#
# Feature engineering often produces more improvement than changing algorithms.
#
# Numerical features
#
# Learn:
#
# Standardization
# Normalization
# Log transformation
# Square-root transformation
# Polynomial features
# Interaction features
# Binning
# Ratio features
# Aggregated features
# Categorical features
#
# Learn:
#
# Ordinal encoding
# Label encoding
# One-hot encoding
# Frequency encoding
# Target encoding, with leakage precautions
# Rare-category grouping
# Unknown-category handling
# Date and time features
#
# Extract:
#
# Year
# Month
# Day
# Day of week
# Weekend indicator
# Quarter
# Duration
# Time since previous event
# Cyclical encoding
# Text features
#
# Learn basic:
#
# Text cleaning
# Tokenization
# Stop-word handling
# Bag of Words
# TF-IDF
# N-grams
# Feature selection
#
# Learn:
#
# Correlation filtering
# Variance threshold
# Chi-square selection
# ANOVA F-test
# Mutual information
# Recursive Feature Elimination
# L1 regularization
# Tree-based feature importance
# Permutation importance
# 5. Supervised Machine Learning
# Regression
#
# Learn in this order:
#
# Simple Linear Regression
# Multiple Linear Regression
# Polynomial Regression
# Ridge Regression
# Lasso Regression
# Elastic Net
# Decision Tree Regressor
# Random Forest Regressor
# Gradient Boosting Regressor
# XGBoost Regressor
# Regression assumptions
#
# Understand:
#
# Linearity
# Independence
# Homoscedasticity
# Normally distributed residuals
# Multicollinearity
# Regression metrics
#
# Master:
#
# MAE
# MSE
# RMSE
# R²
# Adjusted R²
# MAPE, including its limitations
#
# You should understand when MAE is preferable to RMSE and why a negative R² is possible.
#
# Classification
#
# Learn in this order:
#
# Logistic Regression
# K-Nearest Neighbors
# Naive Bayes
# Decision Tree Classifier
# Random Forest Classifier
# Support Vector Machine
# Gradient Boosting
# XGBoost
# LightGBM
# CatBoost
# Classification metrics
#
# Master:
#
# Confusion matrix
# Accuracy
# Precision
# Recall
# Specificity
# F1-score
# ROC curve
# ROC-AUC
# Precision-recall curve
# PR-AUC
# Log loss
# Threshold selection
# Critical interview scenarios
#
# You must know:
#
# Why accuracy is misleading for imbalanced datasets
# When recall is more important than precision
# When precision is more important than recall
# Why ROC-AUC may look optimistic for highly imbalanced data
# How changing the classification threshold affects precision and recall
# 6. Bias, Variance, Overfitting and Underfitting
#
# This is essential for interviews.
#
# Learn:
#
# Training error versus validation error
# Bias
# Variance
# Underfitting
# Overfitting
# Bias-variance trade-off
# Learning curves
# Model complexity
# Regularization
# Early stopping
# Cross-validation
# Diagnosis
# Underfitting
# Poor training performance
# Poor validation performance
# Model is too simple
# Features may be insufficient
# Overfitting
# Excellent training performance
# Poor validation performance
# Model is learning noise
# Model complexity may be excessive
# Solutions
#
# Learn to use:
#
# More representative data
# Better features
# Feature selection
# Regularization
# Cross-validation
# Tree-depth control
# Pruning
# Early stopping
# Data augmentation for deep learning
# 7. Model Validation and Data Splitting
#
# Learn:
#
# Train-test split
# Train-validation-test split
# Random split
# Stratified split
# K-fold cross-validation
# Stratified K-fold
# Group K-fold
# Time-series split
# Important trap: data leakage
#
# Understand leakage caused by:
#
# Scaling before splitting
# Imputing before splitting
# Feature selection using the entire dataset
# Target-derived features
# Including future information
# Duplicate customers appearing in both train and test sets
#
# Preprocessing should generally be fitted only on the training data.
#
# 8. Scikit-learn Pipelines
#
# Pipelines are essential for production-style ML and interviews.
#
# Learn:
#
# Pipeline
# ColumnTransformer
# SimpleImputer
# StandardScaler
# OneHotEncoder
# Numerical and categorical pipelines
# Pipeline-based training
# Pipeline-based inference
# Pipeline serialization
#
# A complete pipeline should conceptually look like:
#
# Plain Text
# 1
# Raw Data
# 2
# ↓
# 3
#
# Show more lines
#
# The major advantage is that the same transformations are applied consistently during training and inference.
#
# 9. Hyperparameter Tuning
#
# Learn:
#
# Parameters versus hyperparameters
# Grid search
# Random search
# Bayesian optimization
# Cross-validation during tuning
# Early stopping
# Correct scoring metric selection
#
# Tools:
#
# GridSearchCV
# RandomizedSearchCV
# Optuna
# Important interview point
#
# Do not tune using the final test set.
#
# Correct sequence:
#
# Plain Text
# 1
# Training
# Show more lines
# 10. Tree-Based and Boosting Models
#
# These models are extremely important for tabular data.
#
# Decision trees
#
# Understand:
#
# Root node
# Splitting
# Leaf node
# Gini impurity
# Entropy
# Information gain
# Tree depth
# Minimum samples
# Pruning
# Random forest
#
# Understand:
#
# Bootstrap sampling
# Bagging
# Random feature selection
# Out-of-bag score
# Feature importance
# Why it reduces variance
# Gradient boosting
#
# Understand:
#
# Sequential learning
# Residual correction
# Weak learners
# Learning rate
# Number of estimators
# Tree depth
# Overfitting control
# Libraries
#
# Learn:
#
# XGBoost
# LightGBM
# CatBoost
#
# Because your wine-quality project already uses XGBoost, go deeper into:
#
# n_estimators
# max_depth
# learning_rate
# subsample
# colsample_bytree
# Regularization
# Early stopping
# Feature importance
# SHAP explanations
# 11. Handling Imbalanced Data
#
# Learn:
#
# Class distribution analysis
# Stratified splitting
# Class weights
# Random oversampling
# Random undersampling
# SMOTE
# Threshold adjustment
# Appropriate evaluation metrics
# Important caution
#
# Apply SMOTE only to the training data, not before splitting the dataset.
#
# For imbalanced classification, give attention to:
#
# Precision
# Recall
# F1-score
# PR-AUC
# Class-specific metrics
# Business cost of errors
# 12. Unsupervised Learning
# Clustering
#
# Learn:
#
# K-Means
# Hierarchical clustering
# DBSCAN
#
# Understand:
#
# Choosing the number of clusters
# Elbow method
# Silhouette score
# Distance metrics
# Feature scaling
# Cluster interpretation
# Noise and outlier handling
# Dimensionality reduction
#
# Learn:
#
# PCA
# Explained variance
# Principal components
# Feature scaling before PCA
# t-SNE for visualization
# UMAP as an optional later topic
#
# PCA is used primarily for linear dimensionality reduction, while t-SNE is generally used for visualizing high-dimensional data rather than as a default preprocessing step for predictive models.
#
# 13. SQL for Machine Learning
#
# An ML Engineer frequently needs to retrieve and prepare data before modeling.
#
# Learn:
#
# SELECT
# WHERE
# GROUP BY
# HAVING
# ORDER BY
# Aggregations
# Joins
# Subqueries
# CTEs
# Window functions
# Date functions
# Conditional logic
# Deduplication
# Missing-value analysis
#
# Practice ML-related queries such as:
#
# Customer-level aggregations
# Average transaction amount
# Transaction count over the last 30 days
# Most recent customer activity
# Rolling averages
# Customer churn labels
# Features calculated without future leakage
# 14. Model Explainability
#
# You already use SHAP, which is valuable for your portfolio.
#
# Learn:
#
# Global versus local explanation
# Feature importance
# Permutation importance
# Partial dependence plots
# SHAP values
# SHAP summary plot
# SHAP waterfall plot
# SHAP force plot
# LIME basics
# Interview understanding
#
# Be able to explain:
#
# A global explanation describes overall model behavior.
# A local explanation describes one prediction.
# Tree feature importance may be biased.
# SHAP shows how each feature pushes a prediction relative to a baseline.
# Explanation does not establish causality.
#
# For your wine project, show:
#
# Predicted wine quality
# Prediction probability
# Top positive factors
# Top negative factors
# Global feature importance
# Clear disclaimer that explanations describe model behavior
# 15. Model Serialization
#
# Learn how to save and load complete trained pipelines.
#
# Tools:
#
# joblib
# pickle
# Native XGBoost save/load methods
# PyTorch state_dict
#
# For scikit-learn, save the complete preprocessing and model pipeline, not just the estimator.
#
# Also store:
#
# Model version
# Feature list
# Training timestamp
# Library versions
# Evaluation metrics
# Threshold
# Input schema
#
# Security point: never load an untrusted pickle or joblib file.
#
# 16. FastAPI for Model Serving
#
# After building a model, expose it through an API.
#
# Learn:
#
# REST fundamentals
# GET and POST
# Request body
# Response body
# Pydantic schemas
# Input validation
# Error handling
# Health endpoint
# Prediction endpoint
# Model loading at startup
# API testing
# Swagger documentation
#
# Typical architecture:
#
# Plain Text
# 1
# React UI
# 2
# ↓
# 3
# Spring Boot
# Show more lines
#
# For your existing application, you can retain Spring Boot as the business backend or simplify the ML-serving layer using FastAPI.
#
# 17. Git and GitHub
#
# This is essential for your portfolio and development workflow.
#
# Learn:
#
# Repository creation
# Commit
# Branch
# Merge
# Pull request
# .gitignore
# README
# Requirements file
# Environment variables
# Git tags and releases
# Basic GitHub Actions
#
# Never push:
#
# .venv
# AWS credentials
# API keys
# Corporate data
# Private datasets
# Large model binaries without a suitable storage strategy
# Company source code or documents
# 18. Docker
#
# Learn after FastAPI.
#
# Topics:
#
# Image
# Container
# Dockerfile
# Base image
# Working directory
# Dependency installation
# Exposed port
# Environment variables
# Volumes
# Docker Compose
# Container logs
# Image size optimization
#
# Your goal is to containerize:
#
# Plain Text
# 1
# FastAPI application
# 2
# + preprocessing
# Show more lines
# 19. MLOps
#
# Once you can train and deploy a model manually, learn MLOps.
#
# Experiment tracking
#
# Learn:
#
# Parameters
# Metrics
# Artifacts
# Model versions
# Reproducible runs
#
# Tool:
#
# MLflow
# Data and model versioning
#
# Learn:
#
# Dataset versioning
# Code versioning
# Model versioning
# Reproducibility
# DVC basics
# Production monitoring
#
# Learn:
#
# Input validation
# Data drift
# Concept drift
# Prediction drift
# Model performance degradation
# Latency
# Error rate
# Missing feature rate
# Retraining triggers
# CI/CD
#
# Understand:
#
# Plain Text
# 1
# Code commit
# Show more lines
# 20. AWS for ML Deployment
#
# Since you already passed MLA-C01, convert your service knowledge into implementation.
#
# For your wine-quality project:
#
# Plain Text
# 1
# React UI
# 2
# ↓
# 3
# API/backend
# 4
# ↓
# 5
# SageMaker
# Show more lines
#
# Practice:
#
# Store model artifacts in S3
# Create inference script
# Create SageMaker model
# Deploy a real-time endpoint
# Send test inference requests
# Validate request and response schemas
# Monitor invocation metrics
# Configure logs
# Delete endpoints when not in use to prevent charges
#
# Also understand when to use:
#
# Real-time inference
# Serverless inference
# Asynchronous inference
# Batch Transform
# 21. PyTorch and Deep Learning
#
# Learn PyTorch only after you can confidently build traditional ML workflows.
#
# Mathematical foundations
#
# Understand:
#
# Vectors
# Matrices
# Matrix multiplication
# Derivatives
# Gradients
# Chain rule
# Gradient descent
# Learning rate
# Neural-network concepts
#
# Learn:
#
# Neuron
# Layer
# Weight
# Bias
# Activation function
# Forward propagation
# Loss function
# Backpropagation
# Optimizer
# Epoch
# Batch size
# Regularization
# PyTorch topics
#
# Learn:
#
# Tensors
# Tensor shapes
# Device management
# Automatic differentiation
# Dataset
# DataLoader
# nn.Module
# Forward method
# Loss functions
# Optimizers
# Training loop
# Validation loop
# Model saving and loading
# Early stopping
# GPU or Apple MPS usage
# Activation functions
#
# Learn:
#
# ReLU
# Sigmoid
# Tanh
# Softmax
# Loss functions
#
# Learn:
#
# Mean squared error
# Binary cross-entropy
# Cross-entropy loss
# Optimizers
#
# Learn:
#
# SGD
# Momentum
# Adam
# AdamW
# 22. Choose One Specialization
#
# After foundational ML and deep learning, select one primary track.
#
# NLP
#
# Learn:
#
# Text preprocessing
# Tokenization
# TF-IDF
# Word embeddings
# RNN and LSTM concepts
# Attention
# Transformers
# Hugging Face
# Text classification
# Semantic search
# Computer vision
#
# Learn:
#
# Image tensors
# Image preprocessing
# Data augmentation
# CNNs
# Transfer learning
# Image classification
# Object detection basics
# Time series
#
# Learn:
#
# Trend
# Seasonality
# Lag features
# Rolling statistics
# Time-aware validation
# ARIMA basics
# Forecasting metrics
# Tree-based forecasting
# Deep-learning approaches later
# GenAI
#
# Learn after basic NLP and deep-learning concepts:
#
# Transformer fundamentals
# Embeddings
# Vector databases
# Semantic search
# Prompt engineering
# RAG
# Chunking
# Retrieval evaluation
# LLM evaluation
# Guardrails
# Agent workflows
# Fine-tuning concepts
# Cost and latency optimization
